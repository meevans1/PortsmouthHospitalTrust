# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
import pyodbc

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# Import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
sql_conn = pyodbc.connect('DRIVER={SQL Server};'
                            'SERVER=L_AAGDATIX;'
                            'DATABASE=DatixCRM;'
                            'Trusted_Connection=yes') 
query = "set transaction isolation level read uncommitted select inc_organisation,inc_locactual,inc_unit,inc_specialty,inc_loctype,inc_result,inc_severity,show_other_contacts,show_employee,show_witness,show_document,inc_reportedby,inc_notes from DatixCRM.dbo.incidents_main where inc_type='PAT' and inc_category='MEDIC'"
df = pd.read_sql(query, sql_conn)
df.head()
# Out:
#   inc_organisation inc_locactual inc_unit inc_specialty inc_loctype  \
# 0               QA          E6/7   MEDMED          RESP        WARD
# 1               QA            C5   MEDMED        GENMED        WARD
# 2               QA         EMERG    MEDUR            ED          AE
# 3               QA            C7   MEDMED        CARDIO        WARD
# 4               QA            D5   SURMHN         ORTHO        WARD
#
#   inc_result inc_severity show_other_contacts show_employee show_witness  \
# 0     NOHARM         NONE                None             N            N
# 1       HARM          LOW                None             Y            Y
# 2     NOHARM         NONE                None             N            N
# 3     NOHARM         NONE                None             Y            N
# 4     NOHARM         NONE                None             N            N
#
#   show_document            inc_reportedby  \
# 0             N                      None
# 1             Y                      None
# 2             N                     Other
# 3             N  Other (Nurse / Midwife )
# 4             N                     Nurse
#
#                                            inc_notes
# 0  on drug rounds found Amlodipine not given for ...
# 1  HAEMOPHILIA PATIENT\r\n\r\nPATIENT NOT ADMINIS...
# 2  Resus controlled order booked went missing, ha...
# 3  MIDAZOLAM SIGNED OUT OF CD BOOK FOR PATIENT . ...
# 4  I was giving the oral medication(CD-oxycodone)...

# %%
df['division'] = df['inc_unit'].str[:3]
df['care group'] = df['inc_unit'].str[3:6]
df = df.drop('inc_unit',axis=1)

# %%
df.columns = [column.replace('inc_organisation','site') for column in df.columns]
df.columns = [column.replace('inc_locactual','ward/dept/unit') for column in df.columns]
df.columns = [column.replace('inc_unit','division & care group') for column in df.columns]
df.columns = [column.replace('inc_specialty','specialty') for column in df.columns]
df.columns = [column.replace('inc_loctype','location type') for column in df.columns]
df.columns = [column.replace('inc_result','result') for column in df.columns]
df.columns = [column.replace('inc_severity','severity') for column in df.columns]
df.columns = [column.replace('inc_reportedby','reported by') for column in df.columns]
df.columns = [column.replace('show_other_contacts','other patients involved?') for column in df.columns]
df.columns = [column.replace('show_employee','other employees involved?') for column in df.columns]
df.columns = [column.replace('show_witness','any witnesses?') for column in df.columns]
df.columns = [column.replace('show_document','any documents attached?') for column in df.columns]
df.head()
# Out:
#   site ward/dept/unit specialty location type  result severity  \
# 0   QA           E6/7      RESP          WARD  NOHARM     NONE
# 1   QA             C5    GENMED          WARD    HARM      LOW
# 2   QA          EMERG        ED            AE  NOHARM     NONE
# 3   QA             C7    CARDIO          WARD  NOHARM     NONE
# 4   QA             D5     ORTHO          WARD  NOHARM     NONE
#
#   other patients involved? other employees involved? any witnesses?  \
# 0                     None                         N              N
# 1                     None                         Y              Y
# 2                     None                         N              N
# 3                     None                         Y              N
# 4                     None                         N              N
#
#   any documents attached?               reported by  \
# 0                       N                      None
# 1                       Y                      None
# 2                       N                     Other
# 3                       N  Other (Nurse / Midwife )
# 4                       N                     Nurse
#
#                                            inc_notes division care group
# 0  on drug rounds found Amlodipine not given for ...      MED        MED
# 1  HAEMOPHILIA PATIENT\r\n\r\nPATIENT NOT ADMINIS...      MED        MED
# 2  Resus controlled order booked went missing, ha...      MED         UR
# 3  MIDAZOLAM SIGNED OUT OF CD BOOK FOR PATIENT . ...      MED        MED
# 4  I was giving the oral medication(CD-oxycodone)...      SUR        MHN

# %%
category_columns = list(df.columns.values)
category_columns.remove('inc_notes')
count_accuracies = []
tfidf_accuracies = []
for column in category_columns:
    df_dropped = df.dropna(subset=[column])
    y = df_dropped[column]
    X_train, X_test, y_train, y_test = train_test_split(
                                    df_dropped['inc_notes'], y,
                                    test_size=0.33,
                                    random_state=53)
    count_vectorizer = CountVectorizer(stop_words='english')
    count_train = count_vectorizer.fit_transform(X_train.values)
    count_test = count_vectorizer.transform(X_test.values)
    # Print the first 10 features of the count_vectorizer
    #print(count_vectorizer.get_feature_names()[:10])


    # Initialize a TfidfVectorizer object: tfidf_vectorizer
    tfidf_vectorizer = TfidfVectorizer(stop_words="english",max_df=0.7)

    # Transform the training data: tfidf_train 
    tfidf_train = tfidf_vectorizer.fit_transform(X_train.values)

    # Transform the test data: tfidf_test 
    tfidf_test = tfidf_vectorizer.transform(X_test.values)

    # Print the first 10 features
    #print(tfidf_vectorizer.get_feature_names()[:10])

    # Print the first 5 vectors of the tfidf training data
    #print(tfidf_train.A[:5])


    # Create the CountVectorizer DataFrame: count_df
    #count_df = pd.DataFrame(count_train.A, columns=count_vectorizer.get_feature_names())

    # Create the TfidfVectorizer DataFrame: tfidf_df
    #tfidf_df = pd.DataFrame(tfidf_train.A, columns=tfidf_vectorizer.get_feature_names())

    # Print the head of count_df
    #print(count_df.head())

    # Print the head of tfidf_df
    #print(tfidf_df.head())

    # Calculate the difference in columns: difference
    #difference = set(count_df.columns) - set(tfidf_df.columns)
    #print(difference)

    # Check whether the DataFrames are equal
    #print(count_df.equals(tfidf_df))


    count_nb_classifier = MultinomialNB()
    count_nb_classifier.fit(count_train, y_train)
    count_pred = count_nb_classifier.predict(count_test)
    count_accuracies.append(100*metrics.accuracy_score(y_test,count_pred))
    
    tfidf_nb_classifier = MultinomialNB()
    tfidf_nb_classifier.fit(tfidf_train, y_train)
    tfidf_pred = tfidf_nb_classifier.predict(tfidf_test)
    tfidf_accuracies.append(100*metrics.accuracy_score(y_test,tfidf_pred))

# %%
count_from50 = [int(round(accuracy/2)) for accuracy in count_accuracies]
n_category_columns = len(category_columns)
colors = [['green' if count_from50[j]>i else 'red' for j in range(n_category_columns)] for i in range(50)]
#category_columns = [column.replace('inc_organisation','site') for column in category_columns]
#category_columns = [column.replace('inc_locactual','ward/dept/unit') for column in category_columns]
#category_columns = [column.replace('inc_unit','division & care group') for column in category_columns]
#category_columns = [column.replace('inc_specialty','specialty') for column in category_columns]
#category_columns = [column.replace('inc_loctype','location type') for column in category_columns]
#category_columns = [column.replace('inc_result','result') for column in category_columns]
#category_columns = [column.replace('inc_severity','severity') for column in category_columns]
#category_columns = [column.replace('inc_reportedby','reported by') for column in category_columns]
#category_columns = [column.replace('show_other_contacts','other patients involved?') for column in category_columns]
#category_columns = [column.replace('show_employee','other employees involved?') for column in category_columns]
#category_columns = [column.replace('show_witness','any witnesses?') for column in category_columns]
#category_columns = [column.replace('show_document','any documents attached?') for column in category_columns]
for i in range(50):
    plt.scatter(x=np.ones(len(category_columns))*(i+1),y=category_columns,color=colors[i])
plt.xlim((0,51));
fig1 = plt.figure(1)
fig1.text(0, 0.95, "Correct", ha="center", va="bottom", size="large", color="green");
fig1.text(0.06, 0.95, "/", ha="center", va="bottom", size="large");
fig1.text(0.13,0.95,"Incorrect", ha="center", va="bottom", size="large", color="red");
fig1.text(0.19, 0.95, " prediction from freetext entry for medicine patient safety events", va="bottom", size="large");

# %%
tfidf_from50 = [int(round(accuracy/2)) for accuracy in tfidf_accuracies]
colors = [['green' if tfidf_from50[j]>i else 'red' for j in range(n_category_columns)] for i in range(50)]
for i in range(50):
    plt.scatter(x=np.ones(len(category_columns))*(i+1),y=category_columns,color=colors[i])
plt.xlim((0,51));
fig1 = plt.figure(1)
fig1.text(0, 0.95, "Correct", ha="center", va="bottom", size="large", color="green");
fig1.text(0.06, 0.95, "/", ha="center", va="bottom", size="large");
fig1.text(0.13,0.95,"Incorrect", ha="center", va="bottom", size="large", color="red");
fig1.text(0.19, 0.95, " prediction from freetext entry for medicine patient safety events", va="bottom", size="large");

# %%
def plot_count_confusion_matrix():
    count_accuracies = []
    for column in category_columns:
        df_dropped = df.dropna(subset=[column])
        classes = [str(i) for i in df_dropped[column].value_counts().index]
        mapping = dict((el,i) for i,el in enumerate(classes)) 
        df_replaced = df_dropped.replace({column: mapping})
        y = df_replaced[column]
        X_train, X_test, y_train, y_test = train_test_split(
                                        df_dropped['inc_notes'], y,
                                        test_size=0.33,
                                        random_state=53)
        count_vectorizer = CountVectorizer(stop_words='english')
        count_train = count_vectorizer.fit_transform(X_train.values)
        count_test = count_vectorizer.transform(X_test.values)

        count_nb_classifier = MultinomialNB()
        count_nb_classifier.fit(count_train, y_train)
        count_pred = count_nb_classifier.predict(count_test)
        count_accuracies.append(100*metrics.accuracy_score(y_test,count_pred))

        cm = metrics.confusion_matrix(y_test, count_pred, labels=list(mapping.values()))
    
        plt.figure();
        # https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
        fig, ax = plt.subplots(figsize=(6,6));
        im = ax.imshow(cm, cmap=plt.cm.Blues);
        # create an axes on the right side of ax. The width of cax will be 5%
        # of ax and the padding between cax and ax will be fixed at 0.05 inch.
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        ax.figure.colorbar(im, cax=cax)
        #plt.title('True vs Predicted "'+str(column)+'" from freetext of medicine patient safety events',x=1.2)        
        # We want to show all ticks...
        ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               # ... and label them with the respective list entries
               xticklabels=classes, yticklabels=classes,
               title='True vs Predicted "'+str(column)+'" from freetext of medicine patient safety events',
               ylabel='True label',
               xlabel='Predicted label');
        ax.xaxis.set_label_coords(1.15, -0.05);

        # Rotate the tick labels and set their alignment.
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
                 rotation_mode="anchor");

        # Loop over data dimensions and create text annotations.
        fmt = 'd'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black");
        fig.tight_layout();
        plt.show();

# %%
plot_count_confusion_matrix()

# %%
def plot_tfidf_confusion_matrix():
    tfidf_accuracies = []
    for column in category_columns:
        df_dropped = df.dropna(subset=[column])
        classes = [str(i) for i in df_dropped[column].value_counts().index]
        mapping = dict((el,i) for i,el in enumerate(classes)) 
        df_replaced = df_dropped.replace({column: mapping})
        y = df_replaced[column]
        X_train, X_test, y_train, y_test = train_test_split(
                                        df_dropped['inc_notes'], y,
                                        test_size=0.33,
                                        random_state=53)
        tfidf_vectorizer = TfidfVectorizer(stop_words='english')
        tfidf_train = tfidf_vectorizer.fit_transform(X_train.values)
        tfidf_test = tfidf_vectorizer.transform(X_test.values)

        tfidf_nb_classifier = MultinomialNB()
        tfidf_nb_classifier.fit(tfidf_train, y_train)
        tfidf_pred = tfidf_nb_classifier.predict(tfidf_test)
        tfidf_accuracies.append(100*metrics.accuracy_score(y_test,tfidf_pred))

        cm = metrics.confusion_matrix(y_test, tfidf_pred, labels=list(mapping.values()))
    
        plt.figure();
        # https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
        fig, ax = plt.subplots(figsize=(7,7));
        im = ax.imshow(cm, cmap=plt.cm.Blues);
        # create an axes on the right side of ax. The width of cax will be 5%
        # of ax and the padding between cax and ax will be fixed at 0.05 inch.
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        ax.figure.colorbar(im, cax=cax)
     
        # We want to show all ticks...
        ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               # ... and label them with the respective list entries
               xticklabels=classes, yticklabels=classes,
               title='True vs Predicted "'+str(column)+'" from freetext of medicine patient safety events',
               ylabel='True label',
               xlabel='Predicted label');
        ax.xaxis.set_label_coords(1.15, -0.05);

        # Rotate the tick labels and set their alignment.
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
                 rotation_mode="anchor");

        # Loop over data dimensions and create text annotations.
        fmt = 'd'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black");
        fig.tight_layout();
        plt.show();

# %%
plot_tfidf_confusion_matrix()

# %%
# Create the list of alphas: alphas
alphas = np.arange(0.1,1,0.1)

# Define train_and_predict()
def count_train_and_predict(column,alpha):
    df_dropped = df.dropna(subset=[column])
    y = df_dropped[column]
    X_train, X_test, y_train, y_test = train_test_split(
                                    df_dropped['inc_notes'], y,
                                    test_size=0.33,
                                    random_state=53)

    # Initialize a CountVectorizer object: count_vectorizer
    count_vectorizer = CountVectorizer(stop_words="english")

    # Transform the training data: count_train 
    count_train = count_vectorizer.fit_transform(X_train.values)

    # Transform the test data: count_test 
    count_test = count_vectorizer.transform(X_test.values)
    
    # Instantiate the classifier: nb_classifier
    nb_classifier = MultinomialNB(alpha=alpha)
    # Fit to the training data
    nb_classifier.fit(count_train, y_train)
    # Predict the labels: pred
    pred = nb_classifier.predict(count_test)
    # Compute accuracy: score
    score = metrics.accuracy_score(y_test,pred)
    
    return score

# %%
# Iterate over the alphas and print the corresponding score
for alpha in alphas:
    print('Alpha: ', alpha)
    for column in category_columns:
        print('Column: ', column, ' Score: ', count_train_and_predict(column,alpha))
        print()
# Out:
# Alpha:  0.1
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.3216
#
# Column:  specialty  Score:  0.34912
#
# Column:  location type  Score:  0.6768
#
# Column:  result  Score:  0.72416
#
# Column:  severity  Score:  0.72096
#
# Column:  other patients involved?  Score:  0.9684873949579832
#
# Column:  other employees involved?  Score:  0.72416
#
# Column:  any witnesses?  Score:  0.75328
#
# Column:  any documents attached?  Score:  0.79744
#
# Column:  reported by  Score:  0.528809218950064
#
# Column:  division  Score:  0.63776
#
# Column:  care group  Score:  0.47424
#
# Alpha:  0.2
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.31808
#
# Column:  specialty  Score:  0.352
#
# Column:  location type  Score:  0.68352
#
# Column:  result  Score:  0.72992
#
# Column:  severity  Score:  0.72384
#
# Column:  other patients involved?  Score:  0.9705882352941176
#
# Column:  other employees involved?  Score:  0.72736
#
# Column:  any witnesses?  Score:  0.75168
#
# Column:  any documents attached?  Score:  0.80352
#
# Column:  reported by  Score:  0.5355313700384123
#
# Column:  division  Score:  0.64576
#
# Column:  care group  Score:  0.47872
#
# Alpha:  0.30000000000000004
# Column:  site  Score:  0.97184
#
# Column:  ward/dept/unit  Score:  0.30752
#
# Column:  specialty  Score:  0.34624
#
# Column:  location type  Score:  0.69184
#
# Column:  result  Score:  0.73536
#
# Column:  severity  Score:  0.73376
#
# Column:  other patients involved?  Score:  0.9726890756302521
#
# Column:  other employees involved?  Score:  0.73312
#
# Column:  any witnesses?  Score:  0.75712
#
# Column:  any documents attached?  Score:  0.80864
#
# Column:  reported by  Score:  0.5547375160051217
#
# Column:  division  Score:  0.64608
#
# Column:  care group  Score:  0.4816
#
# Alpha:  0.4
# Column:  site  Score:  0.97312
#
# Column:  ward/dept/unit  Score:  0.29952
#
# Column:  specialty  Score:  0.3408
#
# Column:  location type  Score:  0.69312
#
# Column:  result  Score:  0.73888
#
# Column:  severity  Score:  0.73536
#
# Column:  other patients involved?  Score:  0.9744397759103641
#
# Column:  other employees involved?  Score:  0.74208
#
# Column:  any witnesses?  Score:  0.76128
#
# Column:  any documents attached?  Score:  0.81472
#
# Column:  reported by  Score:  0.5585787451984635
#
# Column:  division  Score:  0.64448
#
# Column:  care group  Score:  0.48448
#
# Alpha:  0.5
# Column:  site  Score:  0.97376
#
# Column:  ward/dept/unit  Score:  0.29344
#
# Column:  specialty  Score:  0.33408
#
# Column:  location type  Score:  0.69344
#
# Column:  result  Score:  0.74272
#
# Column:  severity  Score:  0.74048
#
# Column:  other patients involved?  Score:  0.9747899159663865
#
# Column:  other employees involved?  Score:  0.75008
#
# Column:  any witnesses?  Score:  0.76224
#
# Column:  any documents attached?  Score:  0.81984
#
# Column:  reported by  Score:  0.5633802816901409
#
# Column:  division  Score:  0.64544
#
# Column:  care group  Score:  0.48256
#
# Alpha:  0.6
# Column:  site  Score:  0.97344
#
# Column:  ward/dept/unit  Score:  0.28576
#
# Column:  specialty  Score:  0.32768
#
# Column:  location type  Score:  0.70016
#
# Column:  result  Score:  0.74848
#
# Column:  severity  Score:  0.74688
#
# Column:  other patients involved?  Score:  0.9747899159663865
#
# Column:  other employees involved?  Score:  0.75264
#
# Column:  any witnesses?  Score:  0.76608
#
# Column:  any documents attached?  Score:  0.82624
#
# Column:  reported by  Score:  0.5659411011523687
#
# Column:  division  Score:  0.6464
#
# Column:  care group  Score:  0.48384
#
# Alpha:  0.7000000000000001
# Column:  site  Score:  0.97312
#
# Column:  ward/dept/unit  Score:  0.27872
#
# Column:  specialty  Score:  0.32288
#
# Column:  location type  Score:  0.70464
#
# Column:  result  Score:  0.75328
#
# Column:  severity  Score:  0.7504
#
# Column:  other patients involved?  Score:  0.9751400560224089
#
# Column:  other employees involved?  Score:  0.75808
#
# Column:  any witnesses?  Score:  0.77088
#
# Column:  any documents attached?  Score:  0.83072
#
# Column:  reported by  Score:  0.5688220230473752
#
# Column:  division  Score:  0.64384
#
# Column:  care group  Score:  0.47968
#
# Alpha:  0.8
# Column:  site  Score:  0.97344
#
# Column:  ward/dept/unit  Score:  0.2736
#
# Column:  specialty  Score:  0.31776
#
# Column:  location type  Score:  0.70304
#
# Column:  result  Score:  0.75776
#
# Column:  severity  Score:  0.75328
#
# Column:  other patients involved?  Score:  0.9751400560224089
#
# Column:  other employees involved?  Score:  0.75872
#
# Column:  any witnesses?  Score:  0.7712
#
# Column:  any documents attached?  Score:  0.8336
#
# Column:  reported by  Score:  0.5717029449423816
#
# Column:  division  Score:  0.64096
#
# Column:  care group  Score:  0.47808
#
# Alpha:  0.9
# Column:  site  Score:  0.97376
#
# Column:  ward/dept/unit  Score:  0.26592
#
# Column:  specialty  Score:  0.31136
#
# Column:  location type  Score:  0.70208
#
# Column:  result  Score:  0.75872
#
# Column:  severity  Score:  0.75616
#
# Column:  other patients involved?  Score:  0.9751400560224089
#
# Column:  other employees involved?  Score:  0.76128
#
# Column:  any witnesses?  Score:  0.77504
#
# Column:  any documents attached?  Score:  0.83904
#
# Column:  reported by  Score:  0.5707426376440461
#
# Column:  division  Score:  0.64128
#
# Column:  care group  Score:  0.47456

# %%
# Create the list of alphas: alphas
alphas = np.arange(0.1,1,0.1)

# Define train_and_predict()
def tfidf_train_and_predict(column,alpha):
    df_dropped = df.dropna(subset=[column])
    y = df_dropped[column]
    X_train, X_test, y_train, y_test = train_test_split(
                                    df_dropped['inc_notes'], y,
                                    test_size=0.33,
                                    random_state=53)

    # Initialize a TfidfVectorizer object: tfidf_vectorizer
    tfidf_vectorizer = TfidfVectorizer(stop_words="english",max_df=0.7)

    # Transform the training data: tfidf_train 
    tfidf_train = tfidf_vectorizer.fit_transform(X_train.values)

    # Transform the test data: tfidf_test 
    tfidf_test = tfidf_vectorizer.transform(X_test.values)
    
    # Instantiate the classifier: nb_classifier
    nb_classifier = MultinomialNB(alpha=alpha)
    # Fit to the training data
    nb_classifier.fit(tfidf_train, y_train)
    # Predict the labels: pred
    pred = nb_classifier.predict(tfidf_test)
    # Compute accuracy: score
    score = metrics.accuracy_score(y_test,pred)
    
    # Get the class labels: class_labels
    class_labels = nb_classifier.classes_

    # Extract the features: feature_names
    feature_names = tfidf_vectorizer.get_feature_names()

    # Zip the feature names together with the coefficient array and sort by weights: feat_with_weights
    feat_with_weights = sorted(zip(nb_classifier.coef_[0], feature_names))

    # Print the first class label and the bottom 20  feat_with_weights entries
    #for i in range(len(class_labels)):
    #    print(class_labels[i], feat_with_weights[-20:])
    
    return score

# %%
# Iterate over the alphas and print the corresponding score
for alpha in alphas:
    print('Alpha: ', alpha)
    for column in category_columns:
        print('Column: ', column, ' Score: ', tfidf_train_and_predict(column,alpha))
        print()
# Out:
# Alpha:  0.1
# Column:  site  Score:  0.97184
#
# Column:  ward/dept/unit  Score:  0.27488
#
# Column:  specialty  Score:  0.32416
#
# Column:  location type  Score:  0.69888
#
# Column:  result  Score:  0.76992
#
# Column:  severity  Score:  0.76832
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.79648
#
# Column:  any witnesses?  Score:  0.80896
#
# Column:  any documents attached?  Score:  0.85632
#
# Column:  reported by  Score:  0.5806658130601793
#
# Column:  division  Score:  0.63584
#
# Column:  care group  Score:  0.46464
#
# Alpha:  0.2
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.25216
#
# Column:  specialty  Score:  0.2976
#
# Column:  location type  Score:  0.68704
#
# Column:  result  Score:  0.7728
#
# Column:  severity  Score:  0.76992
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.79936
#
# Column:  any witnesses?  Score:  0.81504
#
# Column:  any documents attached?  Score:  0.85376
#
# Column:  reported by  Score:  0.5825864276568502
#
# Column:  division  Score:  0.62624
#
# Column:  care group  Score:  0.44704
#
# Alpha:  0.30000000000000004
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.23904
#
# Column:  specialty  Score:  0.27904
#
# Column:  location type  Score:  0.67232
#
# Column:  result  Score:  0.77184
#
# Column:  severity  Score:  0.76896
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.8016
#
# Column:  any witnesses?  Score:  0.81472
#
# Column:  any documents attached?  Score:  0.85376
#
# Column:  reported by  Score:  0.5857874519846351
#
# Column:  division  Score:  0.60992
#
# Column:  care group  Score:  0.432
#
# Alpha:  0.4
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.22784
#
# Column:  specialty  Score:  0.26208
#
# Column:  location type  Score:  0.66368
#
# Column:  result  Score:  0.76832
#
# Column:  severity  Score:  0.76544
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80192
#
# Column:  any witnesses?  Score:  0.81376
#
# Column:  any documents attached?  Score:  0.85184
#
# Column:  reported by  Score:  0.5893085787451985
#
# Column:  division  Score:  0.59584
#
# Column:  care group  Score:  0.41472
#
# Alpha:  0.5
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.22304
#
# Column:  specialty  Score:  0.25152
#
# Column:  location type  Score:  0.66016
#
# Column:  result  Score:  0.7648
#
# Column:  severity  Score:  0.76288
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80192
#
# Column:  any witnesses?  Score:  0.81408
#
# Column:  any documents attached?  Score:  0.8528
#
# Column:  reported by  Score:  0.5902688860435339
#
# Column:  division  Score:  0.57824
#
# Column:  care group  Score:  0.40416
#
# Alpha:  0.6
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.2208
#
# Column:  specialty  Score:  0.24288
#
# Column:  location type  Score:  0.65728
#
# Column:  result  Score:  0.76352
#
# Column:  severity  Score:  0.7632
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80224
#
# Column:  any witnesses?  Score:  0.8144
#
# Column:  any documents attached?  Score:  0.85248
#
# Column:  reported by  Score:  0.5893085787451985
#
# Column:  division  Score:  0.56576
#
# Column:  care group  Score:  0.38976
#
# Alpha:  0.7000000000000001
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.21728
#
# Column:  specialty  Score:  0.23808
#
# Column:  location type  Score:  0.65504
#
# Column:  result  Score:  0.76256
#
# Column:  severity  Score:  0.76128
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80224
#
# Column:  any witnesses?  Score:  0.816
#
# Column:  any documents attached?  Score:  0.8528
#
# Column:  reported by  Score:  0.5893085787451985
#
# Column:  division  Score:  0.55072
#
# Column:  care group  Score:  0.38368
#
# Alpha:  0.8
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.21568
#
# Column:  specialty  Score:  0.23392
#
# Column:  location type  Score:  0.65312
#
# Column:  result  Score:  0.75936
#
# Column:  severity  Score:  0.75712
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80224
#
# Column:  any witnesses?  Score:  0.81472
#
# Column:  any documents attached?  Score:  0.8528
#
# Column:  reported by  Score:  0.5886683738796414
#
# Column:  division  Score:  0.54176
#
# Column:  care group  Score:  0.37376
#
# Alpha:  0.9
# Column:  site  Score:  0.97152
#
# Column:  ward/dept/unit  Score:  0.21504
#
# Column:  specialty  Score:  0.23008
#
# Column:  location type  Score:  0.65216
#
# Column:  result  Score:  0.75616
#
# Column:  severity  Score:  0.75584
#
# Column:  other patients involved?  Score:  0.9758403361344538
#
# Column:  other employees involved?  Score:  0.80224
#
# Column:  any witnesses?  Score:  0.81472
#
# Column:  any documents attached?  Score:  0.8528
#
# Column:  reported by  Score:  0.5880281690140845
#
# Column:  division  Score:  0.52896
#
# Column:  care group  Score:  0.36704
