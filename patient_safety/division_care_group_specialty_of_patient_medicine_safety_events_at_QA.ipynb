# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pyodbc
import regex as re

# %%
sql_conn = pyodbc.connect('DRIVER={SQL Server};'
                            'SERVER=L_AAGDATIX;'
                            'DATABASE=DatixCRM;'
                            'Trusted_Connection=yes') 
query = "set transaction isolation level read uncommitted select b.description, c.description, d.description from DatixCRM.dbo.code_unit b join DatixCRM.dbo.incidents_main a on a.inc_unit = b.code join DatixCRM.dbo.code_specialty c on a.inc_specialty = c.code join DatixCRM.dbo.code_locactual d on a.inc_locactual=d.code where a.inc_type='PAT' and a.inc_category='MEDIC' and a.inc_organisation='QA' and d.cod_parent2='QA'"
df = pd.read_sql(query, sql_conn)
df.columns = ['division-care_group','specialty','location']
df.head()
# Out:
#                                  division-care_group             specialty  \
# 0         Medicine & Urgent Care Division - Medicine           Respiratory
# 1         Medicine & Urgent Care Division - Medicine      General Medicine
# 2    Medicine and Urgent Care Division - Urgent Care  Emergency Department
# 3         Medicine & Urgent Care Division - Medicine            Cardiology
# 4  Surgical and Outpatients Division - MSK / Head...           Orthopaedic
#
#                     location
# 0                       E6/7
# 1                         C5
# 2  Emergency Department (ED)
# 3                         C7
# 4                         D5

# %%
df['division-care_group'] = df['division-care_group'].str.replace(' and ',' & ')
divider = df['division-care_group'].str.split(" Division - ",n=1,expand=True)
df['division'] = divider[0]
df['care_group'] = divider[1]
#df['division'] = df['division'].str.replace(' and ',' & ')
df.loc[df.division == 'Corporate Functions', 'care_group'] = 'Corporate Functions'
df = df[df['division-care_group'] != 'Corporate Functions']
df = df[df.care_group != 'Pathology']
df = df[df.care_group != 'Patient Administration Services']
#df.loc[df.division == 'Surgical & Outpatients', 'division'] = 'Surgical & Outpatients + Corporate Functions'
#df.loc[df.division == 'Corporate Functions', 'division'] = 'Surgical & Outpatients + Corporate Functions'

# %%
division_counts = df['division'].value_counts()
division_percentages = 100*division_counts/sum(division_counts.values)
division_labels = [str(i) for i in division_counts.index]
print(division_percentages)
# Out:
# Medicine & Urgent Care    45.448438
# Networked Services        20.658381
# Clinical Delivery         17.064159
# Surgical & Outpatients    16.829023
# Name: division, dtype: float64

# %%
df['division_sorted'] = pd.Categorical(df['division'], division_labels)
df = df.sort_values("division_sorted")
df.head()
# Out:
#                                 division-care_group             specialty  \
# 0        Medicine & Urgent Care Division - Medicine           Respiratory
# 3149  Medicine & Urgent Care Division - Urgent Care           Paediatrics
# 3151  Medicine & Urgent Care Division - Urgent Care  Emergency Department
# 3152  Medicine & Urgent Care Division - Urgent Care  Emergency Department
# 3153  Medicine & Urgent Care Division - Urgent Care  Emergency Department
#
#                                 location                division   care_group  \
# 0                                   E6/7  Medicine & Urgent Care     Medicine
# 3149  Emergency Department (Paediatrics)  Medicine & Urgent Care  Urgent Care
# 3151           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
# 3152           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
# 3153           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
#
#              division_sorted
# 0     Medicine & Urgent Care
# 3149  Medicine & Urgent Care
# 3151  Medicine & Urgent Care
# 3152  Medicine & Urgent Care
# 3153  Medicine & Urgent Care

# %%
care_group_labels = []
for i in division_counts.index:
    df_division = df[df.division == i]
    per_division_counts = df_division['care_group'].value_counts()
    care_group_labels += [str(i) for i in per_division_counts.index]
print(care_group_labels)
# Out:
# ['Urgent Care', 'Medicine', 'Older Persons Medicine', "Women & Children's", 'Regional Cancer Centre', 'Renal & Transplantation', 'Pharmacy', 'Critical Care, Theatres, Anaesthetics & HSDU', 'Imaging Radiology', 'MSK / Head & Neck', 'Surgery']

# %%
df['care_group_sorted'] = pd.Categorical(df['care_group'], care_group_labels)
df = df.sort_values(['division_sorted','care_group_sorted'])
df.head()
# Out:
#                                 division-care_group             specialty  \
# 3149  Medicine & Urgent Care Division - Urgent Care           Paediatrics
# 3151  Medicine & Urgent Care Division - Urgent Care  Emergency Department
# 3152  Medicine & Urgent Care Division - Urgent Care  Emergency Department
# 3153  Medicine & Urgent Care Division - Urgent Care  Emergency Department
# 3157  Medicine & Urgent Care Division - Urgent Care  Emergency Department
#
#                                 location                division   care_group  \
# 3149  Emergency Department (Paediatrics)  Medicine & Urgent Care  Urgent Care
# 3151           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
# 3152           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
# 3153           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
# 3157           Emergency Department (ED)  Medicine & Urgent Care  Urgent Care
#
#              division_sorted care_group_sorted
# 3149  Medicine & Urgent Care       Urgent Care
# 3151  Medicine & Urgent Care       Urgent Care
# 3152  Medicine & Urgent Care       Urgent Care
# 3153  Medicine & Urgent Care       Urgent Care
# 3157  Medicine & Urgent Care       Urgent Care

# %%
care_group_counts = df['care_group'].value_counts()[df['care_group'].unique()]
care_group_percentages = 100*care_group_counts/sum(care_group_counts.values)
print(care_group_percentages)
# Out:
# Urgent Care                                     18.911656
# Medicine                                        17.568021
# Older Persons Medicine                           8.968760
# Women & Children's                              10.066062
# Regional Cancer Centre                           7.042884
# Renal & Transplantation                          3.549435
# Pharmacy                                        11.823984
# Critical Care, Theatres, Anaesthetics & HSDU     4.299631
# Imaging Radiology                                0.940544
# MSK / Head & Neck                                9.573396
# Surgery                                          7.255626
# Name: care_group, dtype: float64

# %%
# Create colors
a, b, c, d, e =[plt.cm.Reds, plt.cm.Oranges, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
a, c, d, e = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
inner_ring_colours = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
division_colour_dict = {'Medicine & Urgent Care':plt.cm.Reds, 'Networked Services':plt.cm.Greens, 'Surgical & Outpatients':plt.cm.Blues, 'Clinical Delivery':plt.cm.Purples}

# First Ring (Inside)
fig, ax = plt.subplots()
ax.axis('equal')
division_labels_newlines = [i.replace(' ','\n') for i in division_labels]
#mypie, _ = ax.pie(division_counts, radius=2, labels=division_labels_newlines, labeldistance=0.6, colors=[a(0.9), b(0.9), c(0.9), d(0.9), e(0.9)], textprops={'color':'w'})
mypie, _ = ax.pie(division_counts, radius=1.9, labels=division_labels_newlines, labeldistance=0.5, colors=[inner_ring_colours[0](0.9), inner_ring_colours[1](0.9), inner_ring_colours[2](0.9), inner_ring_colours[3](0.9)], textprops={'color':'w'}, startangle=90, counterclock=False)
plt.setp( mypie, width=1.9, edgecolor='white')
 
# Second Ring (oUTside)
#care_group_colours = [a(0.8), a(0.7), a(0.6), a(0.5), b(0.8), c(0.8), c(0.7), c(0.6), d(0.8), d(0.7), d(0.6), e(0.8), e(0.7), e(0.6)]
care_group_colours = []
for i,index in enumerate(division_counts.index):
    df_division = df[df.division == index]
    per_division_counts = df_division['care_group'].value_counts()
    slice_colour = 8
    for j in range(len(per_division_counts)):
        care_group_colours.append(inner_ring_colours[i](slice_colour/10))
        slice_colour -= 1

mypie2, texts = ax.pie(care_group_counts, radius=2.2, labels=care_group_labels, colors=care_group_colours, startangle=90, counterclock=False)
plt.setp( mypie2, width=0.4, edgecolor='white')
for text, color in zip(texts, care_group_colours):
    text.set_color(color)
plt.margins(0,0)

plt.title('Medicine patient safety events at QA - division (inner ring) and care group (outer ring)', y=1.6);

# %%
specialty_counts = df['specialty'].value_counts()[df['specialty'].unique()]
print(specialty_counts.index)
# Out:
# Index(['Paediatrics', 'Emergency Department', 'Acute Medical Unit',
#        'Respiratory', 'Pharmacy', 'General Medicine', 'Acute Stroke',
#        'Acute Medicine for Older People', 'Cardiology', 'Emergency Surgery',
#        'Maxillofacial', 'Haematology', 'Orthopaedic', 'Ear Nose and Throat',
#        'Nephrology/ Renal medicine', 'Gastroenterology',
#        'Administration Emergency', 'Rheumatology',
#        'Diabetics and Endocrinology', 'Urology', 'Plastic Surgery',
#        'General Surgery', 'Hospital at Night', 'QA@Home Medicine',
#        'Ophthalmology', 'Mental Health', 'Oncology', 'Vascular Services',
#        'Administration Medicine Clinical Service Centre',
#        'Neuro Rehabilitation', 'Pathology', 'Stroke Rehabilitation',
#        'Administration Medicine for Older People', 'Occupational Therapy',
#        'QA@Home Medicine for Older People',
#        'Rehabilitation Services (Orthotics)', 'Obstetrics and Maternity',
#        'Gynaecology', 'NICU', 'Administration Women and Childrens Services',
#        'Anaesthetics', 'Theatres', 'Breast Care', 'Critical Care',
#        'Childrens Safeguarding Team', 'Administration Surgery & Cancer',
#        'Clinical Oncology (radiotherapy)', 'Upper GI Surgery', 'Renal Surgery',
#        'Administration Renal Services',
#        'Administration Clinical Support Services', 'QA@ Home Surgical',
#        'Research', 'Day Surgery Unit', 'Colorectal Surgery', 'Neurology',
#        'Pre-Operative Assessment (POA)', 'Administration CHAT', 'Acute pain',
#        'Diagnostic Imaging', 'Nuclear Medicine Physics', 'QA@Home MSK',
#        'Administration MSK', 'Outpatients', 'Theatres Admissions Suite (TAS)',
#        'Chronic Pain and Pain', 'Oral Surgery'],
#       dtype='object')

# %%
specialty_labels = []
for i in care_group_counts.index:
    df_care_group = df[df.care_group == i]
    per_care_group_counts = df_care_group['specialty'].value_counts()
    specialty_labels += [i + ' - ' + str(j) for j in per_care_group_counts.index]
print(specialty_labels)
# Out:
# ['Urgent Care - Acute Medical Unit', 'Urgent Care - Emergency Department', 'Urgent Care - General Medicine', 'Urgent Care - Acute Medicine for Older People', 'Urgent Care - Paediatrics', 'Urgent Care - Respiratory', 'Urgent Care - Acute Stroke', 'Urgent Care - Cardiology', 'Urgent Care - Pharmacy', 'Urgent Care - Orthopaedic', 'Urgent Care - Gastroenterology', 'Urgent Care - Haematology', 'Urgent Care - Urology', 'Urgent Care - Administration Emergency', 'Urgent Care - Nephrology/ Renal medicine', 'Urgent Care - General Surgery', 'Urgent Care - Ear Nose and Throat', 'Urgent Care - Oncology', 'Urgent Care - Emergency Surgery', 'Urgent Care - Rheumatology', 'Urgent Care - Diabetics and Endocrinology', 'Urgent Care - Maxillofacial', 'Urgent Care - QA@Home Medicine', 'Urgent Care - Plastic Surgery', 'Urgent Care - Vascular Services', 'Urgent Care - Hospital at Night', 'Urgent Care - Ophthalmology', 'Urgent Care - Mental Health', 'Medicine - General Medicine', 'Medicine - Cardiology', 'Medicine - Respiratory', 'Medicine - Gastroenterology', 'Medicine - Acute Medical Unit', 'Medicine - Diabetics and Endocrinology', 'Medicine - Administration Medicine Clinical Service Centre', 'Medicine - Acute Medicine for Older People', 'Medicine - General Surgery', 'Medicine - Pharmacy', 'Medicine - Urology', 'Medicine - Stroke Rehabilitation', 'Medicine - Neuro Rehabilitation', 'Medicine - Acute Stroke', 'Medicine - Administration Medicine for Older People', 'Medicine - Emergency Department', 'Medicine - Vascular Services', 'Medicine - Pathology', 'Older Persons Medicine - Acute Medicine for Older People', 'Older Persons Medicine - Acute Stroke', 'Older Persons Medicine - Stroke Rehabilitation', 'Older Persons Medicine - Neuro Rehabilitation', 'Older Persons Medicine - Pharmacy', 'Older Persons Medicine - General Medicine', 'Older Persons Medicine - QA@Home Medicine for Older People', 'Older Persons Medicine - Orthopaedic', 'Older Persons Medicine - Rehabilitation Services (Orthotics)', 'Older Persons Medicine - Pathology', 'Older Persons Medicine - Administration Medicine for Older People', 'Older Persons Medicine - Occupational Therapy', "Women & Children's - Obstetrics and Maternity", "Women & Children's - NICU", "Women & Children's - Paediatrics", "Women & Children's - Gynaecology", "Women & Children's - Administration Women and Childrens Services", "Women & Children's - Acute Medicine for Older People", "Women & Children's - Acute Medical Unit", "Women & Children's - Urology", "Women & Children's - General Medicine", "Women & Children's - Anaesthetics", "Women & Children's - Pharmacy", "Women & Children's - Orthopaedic", "Women & Children's - Breast Care", "Women & Children's - Theatres", "Women & Children's - Childrens Safeguarding Team", "Women & Children's - Cardiology", "Women & Children's - General Surgery", "Women & Children's - Administration Medicine for Older People", "Women & Children's - Respiratory", "Women & Children's - Critical Care", "Women & Children's - Administration Medicine Clinical Service Centre", 'Regional Cancer Centre - Oncology', 'Regional Cancer Centre - Haematology', 'Regional Cancer Centre - Pathology', 'Regional Cancer Centre - Clinical Oncology (radiotherapy)', 'Regional Cancer Centre - Administration Surgery & Cancer', 'Regional Cancer Centre - General Medicine', 'Regional Cancer Centre - Respiratory', 'Regional Cancer Centre - Upper GI Surgery', 'Regional Cancer Centre - Paediatrics', 'Regional Cancer Centre - Acute Medicine for Older People', 'Regional Cancer Centre - Cardiology', 'Regional Cancer Centre - General Surgery', 'Renal & Transplantation - Nephrology/ Renal medicine', 'Renal & Transplantation - Renal Surgery', 'Renal & Transplantation - Administration Renal Services', 'Renal & Transplantation - Pharmacy', 'Renal & Transplantation - General Medicine', 'Renal & Transplantation - Administration Clinical Support Services', 'Renal & Transplantation - Acute Medical Unit', 'Renal & Transplantation - Ort ...

# %%
specialty_labels = [re.sub(r"Surgery\s-\s(.+)\sSurgery",r"Surgery - \1",s) for s in specialty_labels]
df.specialty = df.specialty.str.replace(' Surgery','')
print(specialty_labels)
df['care_group-specialty'] = df['care_group'] + ' - ' + df['specialty']
df['specialty_sorted'] = pd.Categorical(df['care_group-specialty'], specialty_labels)
df = df.sort_values(['division_sorted','care_group_sorted','specialty_sorted'])
df.head()
# Out:
# ['Urgent Care - Acute Medical Unit', 'Urgent Care - Emergency Department', 'Urgent Care - General Medicine', 'Urgent Care - Acute Medicine for Older People', 'Urgent Care - Paediatrics', 'Urgent Care - Respiratory', 'Urgent Care - Acute Stroke', 'Urgent Care - Cardiology', 'Urgent Care - Pharmacy', 'Urgent Care - Orthopaedic', 'Urgent Care - Gastroenterology', 'Urgent Care - Haematology', 'Urgent Care - Urology', 'Urgent Care - Administration Emergency', 'Urgent Care - Nephrology/ Renal medicine', 'Urgent Care - General Surgery', 'Urgent Care - Ear Nose and Throat', 'Urgent Care - Oncology', 'Urgent Care - Emergency Surgery', 'Urgent Care - Rheumatology', 'Urgent Care - Diabetics and Endocrinology', 'Urgent Care - Maxillofacial', 'Urgent Care - QA@Home Medicine', 'Urgent Care - Plastic Surgery', 'Urgent Care - Vascular Services', 'Urgent Care - Hospital at Night', 'Urgent Care - Ophthalmology', 'Urgent Care - Mental Health', 'Medicine - General Medicine', 'Medicine - Cardiology', 'Medicine - Respiratory', 'Medicine - Gastroenterology', 'Medicine - Acute Medical Unit', 'Medicine - Diabetics and Endocrinology', 'Medicine - Administration Medicine Clinical Service Centre', 'Medicine - Acute Medicine for Older People', 'Medicine - General Surgery', 'Medicine - Pharmacy', 'Medicine - Urology', 'Medicine - Stroke Rehabilitation', 'Medicine - Neuro Rehabilitation', 'Medicine - Acute Stroke', 'Medicine - Administration Medicine for Older People', 'Medicine - Emergency Department', 'Medicine - Vascular Services', 'Medicine - Pathology', 'Older Persons Medicine - Acute Medicine for Older People', 'Older Persons Medicine - Acute Stroke', 'Older Persons Medicine - Stroke Rehabilitation', 'Older Persons Medicine - Neuro Rehabilitation', 'Older Persons Medicine - Pharmacy', 'Older Persons Medicine - General Medicine', 'Older Persons Medicine - QA@Home Medicine for Older People', 'Older Persons Medicine - Orthopaedic', 'Older Persons Medicine - Rehabilitation Services (Orthotics)', 'Older Persons Medicine - Pathology', 'Older Persons Medicine - Administration Medicine for Older People', 'Older Persons Medicine - Occupational Therapy', "Women & Children's - Obstetrics and Maternity", "Women & Children's - NICU", "Women & Children's - Paediatrics", "Women & Children's - Gynaecology", "Women & Children's - Administration Women and Childrens Services", "Women & Children's - Acute Medicine for Older People", "Women & Children's - Acute Medical Unit", "Women & Children's - Urology", "Women & Children's - General Medicine", "Women & Children's - Anaesthetics", "Women & Children's - Pharmacy", "Women & Children's - Orthopaedic", "Women & Children's - Breast Care", "Women & Children's - Theatres", "Women & Children's - Childrens Safeguarding Team", "Women & Children's - Cardiology", "Women & Children's - General Surgery", "Women & Children's - Administration Medicine for Older People", "Women & Children's - Respiratory", "Women & Children's - Critical Care", "Women & Children's - Administration Medicine Clinical Service Centre", 'Regional Cancer Centre - Oncology', 'Regional Cancer Centre - Haematology', 'Regional Cancer Centre - Pathology', 'Regional Cancer Centre - Clinical Oncology (radiotherapy)', 'Regional Cancer Centre - Administration Surgery & Cancer', 'Regional Cancer Centre - General Medicine', 'Regional Cancer Centre - Respiratory', 'Regional Cancer Centre - Upper GI Surgery', 'Regional Cancer Centre - Paediatrics', 'Regional Cancer Centre - Acute Medicine for Older People', 'Regional Cancer Centre - Cardiology', 'Regional Cancer Centre - General Surgery', 'Renal & Transplantation - Nephrology/ Renal medicine', 'Renal & Transplantation - Renal Surgery', 'Renal & Transplantation - Administration Renal Services', 'Renal & Transplantation - Pharmacy', 'Renal & Transplantation - General Medicine', 'Renal & Transplantation - Administration Clinical Support Services', 'Renal & Transplantation - Acute Medical Unit', 'Renal & Transplantation - Ort ...
#                                 division-care_group           specialty  \
# 6428  Medicine & Urgent Care Division - Urgent Care  Acute Medical Unit
# 6420  Medicine & Urgent Care Division - Urgent Care  Acute Medical Unit
# 6412  Medicine & Urgent Care Division - Urgent Care  Acute Medical Unit
# 6443  Medicine & Urgent Care Division - Urgent Care  Acute Medical Unit
# 3099  Medicine & Urgent Care Division - Urgent Care  Acute Medical Unit
#
#                             location                division   care_group  \
# 6428  Acute Medical Unit (AMU) (MAU)  Medicine & Urgent Care  Urgent Care
# 6420  Acute Medical Unit (AMU) (MAU)  Medicine & Urgent Care  Urgent Care
# 6412  Acute Medical Unit (AMU) (MAU)  Medicine & Urgent Care  Urgent Care
# 6443                              D2  Medicine & Urgent Care  Urgent Care
# 3099  Acute Medical Unit (AMU) (MAU)  Medicine & Urgent Care  Urgent Care
#
#              division_sorted care_group_sorted  \
# 6428  Medicine & Urgent Care       Urgent Care
# 6420  Medicine & Urgent Care       Urgent Care
# 6412  Medicine & Urgent Care       Urgent Care
# 6443  Medicine & Urgent Care       Urgent Care
# 3099  Medicine & Urgent Care       Urgent Care
#
#                   care_group-specialty                  specialty_sorted
# 6428  Urgent Care - Acute Medical Unit  Urgent Care - Acute Medical Unit
# 6420  Urgent Care - Acute Medical Unit  Urgent Care - Acute Medical Unit
# 6412  Urgent Care - Acute Medical Unit  Urgent Care - Acute Medical Unit
# 6443  Urgent Care - Acute Medical Unit  Urgent Care - Acute Medical Unit
# 3099  Urgent Care - Acute Medical Unit  Urgent Care - Acute Medical Unit

# %%
specialty_counts = df['care_group-specialty'].value_counts()[df['care_group-specialty'].unique()]
specialty_percentages = 100*specialty_counts/sum(specialty_counts.values)

# %%
for specialty,percentage in specialty_percentages.iteritems():
    if percentage < 0.855827:
        df.loc[df['care_group-specialty'] == specialty, 'care_group-specialty'] = specialty.split(" - ")[0] + ' - Other'

# %%
specialty_counts = df['care_group-specialty'].value_counts()[df['care_group-specialty'].unique()]
print(specialty_counts)
specialty_percentages = 100*specialty_counts/sum(specialty_counts.values)
specialty_labels_split = specialty_counts.index.str.split(" - ",n=1)
specialty_labels = [el[1] for el in specialty_labels_split]
print(specialty_percentages)
# Out:
# Urgent Care - Acute Medical Unit                                861
# Urgent Care - Emergency Department                              626
# Urgent Care - Other                                             202
# Medicine - General Medicine                                     503
# Medicine - Cardiology                                           423
# Medicine - Respiratory                                          323
# Medicine - Gastroenterology                                     254
# Medicine - Other                                                 66
# Older Persons Medicine - Acute Medicine for Older People        484
# Older Persons Medicine - Acute Stroke                           169
# Older Persons Medicine - Other                                  148
# Women & Children's - Obstetrics and Maternity                   334
# Women & Children's - NICU                                       231
# Women & Children's - Paediatrics                                204
# Women & Children's - Other                                      130
# Regional Cancer Centre - Oncology                               453
# Regional Cancer Centre - Haematology                            130
# Regional Cancer Centre - Other                                   46
# Renal & Transplantation - Nephrology/ Renal medicine            227
# Renal & Transplantation - Other                                  90
# Pharmacy - Pharmacy                                             865
# Pharmacy - Other                                                191
# Critical Care, Theatres, Anaesthetics & HSDU - Critical Care    143
# Critical Care, Theatres, Anaesthetics & HSDU - Other            241
# Imaging Radiology - Other                                        84
# MSK / Head & Neck - Orthopaedic                                 398
# MSK / Head & Neck - Rheumatology                                165
# MSK / Head & Neck - Ear Nose and Throat                         111
# MSK / Head & Neck - Ophthalmology                                80
# MSK / Head & Neck - Other                                       101
# Surgery - General                                               151
# Surgery - Colorectal                                            135
# Surgery - Emergency                                             110
# Surgery - Upper GI                                               90
# Surgery - Other                                                 162
# Name: care_group-specialty, dtype: int64
# Urgent Care - Acute Medical Unit                                9.640578
# Urgent Care - Emergency Department                              7.009293
# Urgent Care - Other                                             2.261785
# Medicine - General Medicine                                     5.632068
# Medicine - Cardiology                                           4.736312
# Medicine - Respiratory                                          3.616616
# Medicine - Gastroenterology                                     2.844026
# Medicine - Other                                                0.738999
# Older Persons Medicine - Acute Medicine for Older People        5.419326
# Older Persons Medicine - Acute Stroke                           1.892285
# Older Persons Medicine - Other                                  1.657149
# Women & Children's - Obstetrics and Maternity                   3.739783
# Women & Children's - NICU                                       2.586496
# Women & Children's - Paediatrics                                2.284179
# Women & Children's - Other                                      1.455604
# Regional Cancer Centre - Oncology                               5.072220
# Regional Cancer Centre - Haematology                            1.455604
# Regional Cancer Centre - Other                                  0.515060
# Renal & Transplantation - Nephrology/ Renal medicine            2.541709
# Renal & Transplantation - Other                                 1.007726
# Pharmacy - Pharmacy                                             9.685366
# Pharmacy - Other                                                2.138618
# Critical Care, Theatres, Anaesthetics & HSDU - Critical Care    1.601164
# Critical Care, Theatres, Anaesthetics & HSDU - Other            2.698466
# Imaging Radiology - Other                                       0.940544
# MSK / Head & Neck - Orthopaedic                                 4.456388
# MSK / Head & Neck - Rheumatology                                1.847497
# MSK / Head & Neck - Ear Nose and Throat                         1.242862
# MSK / Head & Neck - Ophthalmology                               0.895756
# MSK / Head & Neck - Other                                       1.130892
# Surgery - General                                               1.690740
# Surgery - Colorectal                                            1.511589
# Surgery - Emergency                                             1.231665
# Surgery - Upper GI                                              1.007726
# Surgery - Other                                                 1.813907
# Name: care_group-specialty, dtype: float64

# %%
# Create colors
a, b, c, d, e =[plt.cm.Reds, plt.cm.Oranges, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
a, c, d, e = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
division_colour_dict = {'Medicine & Urgent Care':plt.cm.Reds, 'Networked Services':plt.cm.Greens, 'Surgical & Outpatients':plt.cm.Blues, 'Clinical Delivery':plt.cm.Purples}
inner_ring_colours = [division_colour_dict[division] for division in division_labels]

# First Ring (Inside)
fig, ax = plt.subplots()
ax.axis('equal')
division_labels_newlines = [i.replace(' ','\n') for i in division_labels]
#mypie, _ = ax.pie(division_counts, radius=2, labels=division_labels_newlines, labeldistance=0.6, colors=[a(0.9), b(0.9), c(0.9), d(0.9), e(0.9)], textprops={'color':'w'})
mypie, _ = ax.pie(division_counts, radius=1.9, labels=division_labels_newlines, labeldistance=0.5, colors=[inner_ring_colours[0](0.9), inner_ring_colours[1](0.9), inner_ring_colours[2](0.9), inner_ring_colours[3](0.9)], textprops={'color':'w'}, startangle=90, counterclock=False)
plt.setp( mypie, width=1.9, edgecolor='white')
 
# Second Ring (oUTside)
care_group_labels_newlines = [i.replace(' ','\n') for i in care_group_labels]
care_group_labels_newlines[care_group_labels_newlines.index('Renal\n&\nTransplantation')] = 'Renal &\nTransplantation'
care_group_labels_newlines[care_group_labels_newlines.index('Critical\nCare,\nTheatres,\nAnaesthetics\n&\nHSDU')] = 'Critical Care, Theatres,\nAnaesthetics\n& HSDU'
#care_group_labels_newlines[care_group_labels_newlines.index('Imaging\nRadiology')] = 'Imaging Radiology'
#care_group_colours = [a(0.8), a(0.7), a(0.6), a(0.5), b(0.8), c(0.8), c(0.7), c(0.6), d(0.8), d(0.7), d(0.6), e(0.8), e(0.7), e(0.6)]
care_group_colours = [a(0.8), a(0.7), a(0.6), c(0.8), c(0.7), c(0.6), d(0.8), d(0.7), d(0.6), e(0.8), e(0.7), e(0.6)]
care_group_colours = []
for i,index in enumerate(division_counts.index):
    df_division = df[df.division == index]
    per_division_counts = df_division['care_group'].value_counts()
    slice_colour = 8
    for j in range(len(per_division_counts)):
        care_group_colours.append(inner_ring_colours[i](slice_colour/10))
        slice_colour -= 1
mypie2, texts = ax.pie(care_group_counts, radius=3.6, labels=care_group_labels_newlines, labeldistance=0.6, colors=care_group_colours, textprops={'color':'k'},startangle=90, counterclock=False)
plt.setp( mypie2, width=1.7, edgecolor='white')
care_group_label_colours = ['k' if i%2==0 else 'w' for i in range(len(care_group_counts))]
for text, color in zip(texts, care_group_label_colours):
    text.set_color(color)
plt.margins(0,0)

# Third Ring (oUTside)
specialty_colours = [a(0.5),a(0.49),a(0.48),a(0.47),a(0.4),a(0.39),a(0.38),a(0.37),a(0.36),a(0.35),a(0.34),a(0.33),a(0.32),a(0.31),a(0.30),a(0.29),a(0.28),a(0.27),a(0.26),a(0.25),a(0.24),c(0.50),c(0.49),c(0.48),c(0.47),c(0.46),c(0.45),c(0.40),c(0.39),c(0.38),c(0.37),c(0.36),c(0.30),c(0.29),c(0.28),c(0.27),d(0.50),d(0.40),d(0.39),d(0.38),d(0.37),d(0.30),e(0.50),e(0.49),e(0.48),e(0.47),e(0.46),e(0.45),e(0.44),e(0.40),e(0.39),e(0.38),e(0.37)]
specialty_colours = []
for i,div_index in enumerate(division_counts.index):
    df_division = df[df.division == div_index]
    slice_colour_orig = 0.5
    division_care_group_counts = df_division['care_group'].value_counts()[df_division['care_group'].unique()]
    for j,care_index in enumerate(division_care_group_counts.index):
        df_care_group = df_division[df_division['care_group-specialty'].str.startswith(care_index)]
        per_care_group_counts = df_care_group['care_group-specialty'].value_counts()[df_care_group['care_group-specialty'].unique()]
        slice_colour = slice_colour_orig - j/10
        for k in per_care_group_counts:
            specialty_colours.append(inner_ring_colours[i](slice_colour))
            slice_colour -= 0.01
mypie3, texts = ax.pie(specialty_counts, radius=3.9, labels=specialty_labels, colors=specialty_colours, startangle=90, counterclock=False)
plt.setp( mypie3, width=0.3, edgecolor='white')
for text, color in zip(texts, specialty_colours):
    text.set_color(color)
plt.margins(0,0)

plt.title('Medicine patient safety events at QA - division (inner ring), care group (middle ring), specialty (outer ring)', y=2.3);

# %%
for specialty,percentage in specialty_percentages.iteritems():
    if percentage < 0.860021:
        df.loc[df['care_group-specialty'] == specialty, 'care_group-specialty'] = specialty.split(" - ")[0] + ' - Other'

specialty_counts = df['care_group-specialty'].value_counts()[df['care_group-specialty'].unique()]
specialty_percentages = 100*specialty_counts/sum(specialty_counts.values)
specialty_labels_split = specialty_counts.index.str.split(" - ",n=1)
specialty_labels = [el[1] for el in specialty_labels_split]
print(specialty_percentages)

df.loc[df.location == 'Department of Critical Care (E5) (DCCQ)', 'location'] = 'E5'
df.loc[df.location == 'Acute Medical Unit (AMU) (MAU)', 'location'] = 'AMU'
df.loc[df.location == 'Haematology & Oncology Day Unit (HODU)', 'location'] = 'HODU'
df.loc[df.location == 'Childrens Assesment Unit (CAU)', 'location'] = 'CAU'
df.loc[df.location == 'Hepatology Clinic (Nurse led) (on C5)', 'location'] = 'Hepatology'
df.loc[df.location == 'Cardiac Day Unit (CDU)', 'location'] = 'CDU'
df.loc[df.location == 'Surgical Assessment Unit (SAU)', 'location'] = 'SAU'
df.location = df.location.str.replace(' QA','')
df.location = df.location.str.replace(' Department','')
df.location = df.location.str.replace(' Unit','')
df.location = df.location.str.replace(' Centre','')
df.location = df.location.str.replace(' Clinic','')
df.location = df.location.str.replace(' and ',' & ')
df.loc[df.location == 'Theatre Admissions Suite (TAS)', 'location'] = 'TAS'
df.loc[df.location == 'Pre-Operative Assessment (POA)', 'location'] = 'POA'
df.loc[df.location == 'Theatre - D1', 'location'] = 'D1'
df.loc[df.location == 'Research & Development', 'location'] = 'R&D'
df.loc[df.location == 'Reception (Atrium)', 'location'] = 'Reception'
df.loc[df.location == 'G5 Endoscopy Suites', 'location'] = 'G5'
df.loc[df.location == 'F3 Stroke Rehabilitation', 'location'] = 'F3'
df.loc[df.location == 'F4 Acute Stroke Ward', 'location'] = 'F4'
df.loc[df.location == 'F1  Neuro Rehab', 'location'] = 'F1'
df.loc[df.location == 'Emergency (ED)', 'location'] = 'ED'
df.loc[df.location == 'B6  Antenatal Ward', 'location'] = 'B6'
df.loc[df.location == 'B7 Postnatal Ward', 'location'] = 'B7'
df.loc[df.location == 'B9 NICU', 'location'] = 'B9'
df.loc[df.location == 'A7 Starfish', 'location'] = 'A7'
df.loc[df.location == 'A8 Shipwreck', 'location'] = 'A8'
df.loc[df.location == 'B5  - Mary Rose Ward', 'location'] = 'B5'
df.loc[df.location == 'B8 Labour Ward', 'location'] = 'B8'
df.loc[df.location == 'Radiotherapy  Dept within CHOC', 'location'] = 'Radiotherapy'
df.loc[df.location == 'Surgical High Care (SHCU)', 'location'] = 'SHCU'

location_counts = df['location'].value_counts()[df['location'].unique()]

location_labels = []
for i in care_group_counts.index:
    df_care_group = df[df.care_group == i]
    per_care_group_counts = df_care_group['location'].value_counts()
    location_labels += [i + ' - ' + str(j) for j in per_care_group_counts.index]

df['care_group-location'] = df['care_group'] + ' - ' + df['location']

location_counts = df['care_group-location'].value_counts()[df['care_group-location'].unique()]
location_percentages = 100*location_counts/sum(location_counts.values)

for location,percentage in location_percentages.iteritems():
    if percentage < 0.701596 + 0.000001:
        df.loc[df['care_group-location'] == location, 'care_group-location'] = location.split(" - ")[0] + ' - Other'

location_counts = df['care_group-location'].value_counts()[df['care_group-location'].unique()]
location_percentages = 100*location_counts/sum(location_counts.values)
print(location_percentages)
location_labels_split = location_counts.index.str.split(" - ",n=1)
location_labels = [el[1] for el in location_labels_split]
df_location_percentages = pd.DataFrame(location_percentages)
df_location_percentages['care_group'] = df_location_percentages.index.to_series().str.split(' - ').str[0]
df_care_groups = {}
for care_group in care_group_labels:
    df_care_groups[care_group] = df_location_percentages.loc[df_location_percentages['care_group']==care_group]
# Out:
# Urgent Care - Acute Medical Unit                                9.640578
# Urgent Care - Emergency Department                              7.009293
# Urgent Care - Other                                             2.261785
# Medicine - General Medicine                                     5.632068
# Medicine - Cardiology                                           4.736312
# Medicine - Respiratory                                          3.616616
# Medicine - Gastroenterology                                     2.844026
# Medicine - Other                                                0.738999
# Older Persons Medicine - Acute Medicine for Older People        5.419326
# Older Persons Medicine - Acute Stroke                           1.892285
# Older Persons Medicine - Other                                  1.657149
# Women & Children's - Obstetrics and Maternity                   3.739783
# Women & Children's - NICU                                       2.586496
# Women & Children's - Paediatrics                                2.284179
# Women & Children's - Other                                      1.455604
# Regional Cancer Centre - Oncology                               5.072220
# Regional Cancer Centre - Haematology                            1.455604
# Regional Cancer Centre - Other                                  0.515060
# Renal & Transplantation - Nephrology/ Renal medicine            2.541709
# Renal & Transplantation - Other                                 1.007726
# Pharmacy - Pharmacy                                             9.685366
# Pharmacy - Other                                                2.138618
# Critical Care, Theatres, Anaesthetics & HSDU - Critical Care    1.601164
# Critical Care, Theatres, Anaesthetics & HSDU - Other            2.698466
# Imaging Radiology - Other                                       0.940544
# MSK / Head & Neck - Orthopaedic                                 4.456388
# MSK / Head & Neck - Rheumatology                                1.847497
# MSK / Head & Neck - Ear Nose and Throat                         1.242862
# MSK / Head & Neck - Ophthalmology                               0.895756
# MSK / Head & Neck - Other                                       1.130892
# Surgery - General                                               1.690740
# Surgery - Colorectal                                            1.511589
# Surgery - Emergency                                             1.231665
# Surgery - Upper GI                                              1.007726
# Surgery - Other                                                 1.813907
# Name: care_group-specialty, dtype: float64
# Urgent Care - AMU                                           9.853320
# Urgent Care - Other                                         1.186877
# Urgent Care - ED                                            7.871459
# Medicine - D2                                               2.485724
# Medicine - D7                                               0.806181
# Medicine - D3                                               1.769119
# Medicine - C5                                               2.317770
# Medicine - C6                                               3.818161
# Medicine - Other                                            1.567574
# Medicine - E8                                               2.261785
# Medicine - E6/7                                             1.399619
# Medicine - C7                                               1.142089
# Older Persons Medicine - G3                                 1.063711
# Older Persons Medicine - G2                                 0.783787
# Older Persons Medicine - F2                                 1.321241
# Older Persons Medicine - F4                                 2.149815
# Older Persons Medicine - G1                                 1.052514
# Older Persons Medicine - G4                                 0.962938
# Older Persons Medicine - F3                                 0.895756
# Older Persons Medicine - Other                              0.033591
# Older Persons Medicine - F1                                 0.705408
# Women & Children's - B8                                     1.298847
# Women & Children's - B7                                     1.444407
# Women & Children's - Other                                  2.105027
# Women & Children's - B9                                     2.631284
# Women & Children's - A5/6                                   0.951741
# Women & Children's - A7                                     1.634755
# Regional Cancer Centre - HODU                               2.676072
# Regional Cancer Centre - Other                              0.828575
# Regional Cancer Centre - F6                                 1.254059
# Regional Cancer Centre - F5                                 1.164483
# Regional Cancer Centre - F7                                 1.119695
# Renal & Transplantation - G7                                1.242862
# Renal & Transplantation - Other                             1.477998
# Renal & Transplantation - G9                                0.828575
# Pharmacy - Pharmacy                                        11.823984
# Critical Care, Theatres, Anaesthetics & HSDU - E5           2.049043
# Critical Care, Theatres, Anaesthetics & HSDU - Theatres     1.388422
# Critical Care, Theatres, Anaesthetics & HSDU - Other        0.862165
# Imaging Radiology - Diagnostic Imaging                      0.929347
# Imaging Radiology - Other                                   0.011197
# MSK / Head & Neck - D5                                      1.119695
# MSK / Head & Neck - D6                                      0.951741
# MSK / Head & Neck - D1                                      1.567574
# MSK / Head & Neck - Other                                   1.332438
# MSK / Head & Neck - D8                                      1.780316
# MSK / Head & Neck - D4                                      0.862165
# MSK / Head & Neck - Rheumatology Outpatients                1.959467
# Surgery - Other                                             0.649423
# Surgery - SAU                                               2.183406
# Surgery - E2                                                1.298847
# Surgery - E3                                                1.914679
# Surgery - D7                                                1.209271
# Name: care_group-location, dtype: float64

# %%
plt.rcParams.update({'font.size': 8})

# Create colors
a, b, c, d, e =[plt.cm.Reds, plt.cm.Oranges, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
a, c, d, e = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
division_colour_dict = {'Medicine & Urgent Care':plt.cm.Reds, 'Networked Services':plt.cm.Greens, 'Surgical & Outpatients':plt.cm.Blues, 'Clinical Delivery':plt.cm.Purples}
inner_ring_colours = [division_colour_dict[division] for division in division_labels]

# First Ring (Inside)
fig, ax = plt.subplots()
ax.axis('equal')
division_labels_newlines = [i.replace(' ','\n') for i in division_labels]
division_labels_newlines[division_labels_newlines.index('Surgical\n&\nOutpatients')] = 'Surgical &\nOutpatients'
#mypie, _ = ax.pie(division_counts, radius=2, labels=division_labels_newlines, labeldistance=0.6, colors=[a(0.9), b(0.9), c(0.9), d(0.9), e(0.9)], textprops={'color':'w'})
mypie, _ = ax.pie(division_counts, radius=0.8, labels=division_labels_newlines, labeldistance=0.4, colors=[inner_ring_colours[0](0.9), inner_ring_colours[1](0.9), inner_ring_colours[2](0.9), inner_ring_colours[3](0.9)], textprops={'color':'w'}, startangle=90, counterclock=False)
plt.setp( mypie, width=0.8, edgecolor='white')
 
# Second Ring (oUTside)
care_group_labels_newlines = [i.replace(' ','\n') for i in care_group_labels]
care_group_labels_newlines[care_group_labels_newlines.index('Renal\n&\nTransplantation')] = 'Renal &\nTransplantation'
care_group_labels_newlines[care_group_labels_newlines.index('Critical\nCare,\nTheatres,\nAnaesthetics\n&\nHSDU')] = 'Critical Care, Theatres,\nAnaesthetics\n& HSDU'
#care_group_labels_newlines[care_group_labels_newlines.index('Imaging\nRadiology')] = 'Imaging Radiology'
#care_group_colours = [a(0.8), a(0.7), a(0.6), a(0.5), b(0.8), c(0.8), c(0.7), c(0.6), d(0.8), d(0.7), d(0.6), e(0.8), e(0.7), e(0.6)]
care_group_colours = [a(0.8), a(0.7), a(0.6), c(0.8), c(0.7), c(0.6), d(0.8), d(0.7), d(0.6), e(0.8), e(0.7), e(0.6)]
care_group_colours = []
for i,index in enumerate(division_counts.index):
    df_division = df[df.division == index]
    per_division_counts = df_division['care_group'].value_counts()
    slice_colour = 8
    for j in range(len(per_division_counts)):
        care_group_colours.append(inner_ring_colours[i](slice_colour/10))
        slice_colour -= 1
mypie2, texts = ax.pie(care_group_counts, radius=2.7, labels=care_group_labels_newlines, labeldistance=0.6, colors=care_group_colours, textprops={'color':'k'},startangle=90, counterclock=False)
plt.setp( mypie2, width=1.9, edgecolor='white')
care_group_label_colours = ['k' if i%2==0 else 'w' for i in range(len(care_group_counts))]
for text, color in zip(texts, care_group_label_colours):
    text.set_color(color)
plt.margins(0,0)

# Third Ring (oUTside)
specialty_labels_newlines = [i.replace(' ','\n') for i in specialty_labels]
specialty_labels_newlines[specialty_labels_newlines.index('Ear\nNose\nand\nThroat')] = 'ENT'
specialty_colours = []
for i,div_index in enumerate(division_counts.index):
    df_division = df[df.division == div_index]
    slice_colour_orig = 0.5
    division_care_group_counts = df_division['care_group'].value_counts()[df_division['care_group'].unique()]
    for j,care_index in enumerate(division_care_group_counts.index):
        df_care_group = df_division[df_division['care_group-specialty'].str.startswith(care_index)]
        per_care_group_counts = df_care_group['care_group-specialty'].value_counts()[df_care_group['care_group-specialty'].unique()]
        slice_colour = slice_colour_orig - j/10
        for k in per_care_group_counts:
            specialty_colours.append(inner_ring_colours[i](slice_colour))
            slice_colour -= 0.01
mypie3, texts = ax.pie(specialty_counts, radius=3.6, labels=specialty_labels_newlines, labeldistance=0.8, colors=specialty_colours, startangle=90, counterclock=False)
plt.setp( mypie3, width=0.9, edgecolor='white')
specialty_label_colours = ['k' if i%2==0 else 'gray' for i in range(len(specialty_counts))]
for text, color in zip(texts, specialty_label_colours):
    text.set_color(color)
plt.margins(0,0)

# Fourth Ring (oUTside)
location_colours = [a(0.5),a(0.49),a(0.48),a(0.47),a(0.4),a(0.39),a(0.38),a(0.37),a(0.36),a(0.35),a(0.34),a(0.33),a(0.32),a(0.31),a(0.30),a(0.29),a(0.28),a(0.27),a(0.26),a(0.25),a(0.24),c(0.50),c(0.49),c(0.48),c(0.47),c(0.46),c(0.45),c(0.40),c(0.39),c(0.38),c(0.37),c(0.36),c(0.30),c(0.29),c(0.28),c(0.27),d(0.50),d(0.40),d(0.39),d(0.38),d(0.37),d(0.30),e(0.50),e(0.49),e(0.48),e(0.47),e(0.46),e(0.45),e(0.44),e(0.40),e(0.39),e(0.38),e(0.37)]
location_colours = []
for i,div_index in enumerate(division_counts.index):
    df_division = df[df.division == div_index]
    slice_colour_orig = 0.5
    division_care_group_counts = df_division['care_group'].value_counts()[df_division['care_group'].unique()]
    for j,care_index in enumerate(division_care_group_counts.index):
        df_care_group = df_division[df_division['care_group-location'].str.startswith(care_index)]
        per_care_group_counts = df_care_group['care_group-location'].value_counts()[df_care_group['care_group-location'].unique()]
        slice_colour = slice_colour_orig - j/10
        for k in per_care_group_counts:
            location_colours.append(inner_ring_colours[i](slice_colour))
            slice_colour -= 0.01
mypie4, texts = ax.pie(location_counts, radius=3.9, labels=location_labels, colors=location_colours, startangle=90, counterclock=False)
plt.setp( mypie4, width=0.3, edgecolor='white')
for text, color in zip(texts, location_colours):
    text.set_color(color)
plt.margins(0,0)

# %%
# Create colors
a, b, c, d, e =[plt.cm.Reds, plt.cm.Oranges, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
a, c, d, e = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues, plt.cm.Purples]
division_colour_dict = {'Medicine & Urgent Care':plt.cm.Reds, 'Networked Services':plt.cm.Greens, 'Surgical & Outpatients':plt.cm.Blues, 'Clinical Delivery':plt.cm.Purples}
inner_ring_colours = [division_colour_dict[division] for division in division_labels]

# First Ring (Inside)
fig, ax = plt.subplots()
ax.axis('equal')
division_labels_newlines = [i.replace(' ','\n') for i in division_labels]
#mypie, _ = ax.pie(division_counts, radius=2, labels=division_labels_newlines, labeldistance=0.6, colors=[a(0.9), b(0.9), c(0.9), d(0.9), e(0.9)], textprops={'color':'w'})
mypie, _ = ax.pie(division_counts, radius=1.9, labels=division_labels_newlines, labeldistance=0.5, colors=[a(0.9), c(0.9), d(0.9), e(0.9)], textprops={'color':'w'}, startangle=90, counterclock=False)
plt.setp( mypie, width=1.9, edgecolor='white')

# 2nd Ring (oUTside)
specialty_labels_newlines = [i.replace(' ','\n') for i in specialty_labels]
specialty_labels_newlines[specialty_labels_newlines.index('Ear\nNose\nand\nThroat')] = 'ENT'
specialty_colours = []
for i,div_index in enumerate(division_counts.index):
    df_division = df[df.division == div_index]
    slice_colour_orig = 0.5
    division_care_group_counts = df_division['care_group'].value_counts()[df_division['care_group'].unique()]
    for j,care_index in enumerate(division_care_group_counts.index):
        df_care_group = df_division[df_division['care_group-specialty'].str.startswith(care_index)]
        per_care_group_counts = df_care_group['care_group-specialty'].value_counts()[df_care_group['care_group-specialty'].unique()]
        slice_colour = slice_colour_orig - j/10
        for k in per_care_group_counts:
            specialty_colours.append(inner_ring_colours[i](slice_colour))
            slice_colour -= 0.01
mypie3, texts = ax.pie(specialty_counts, radius=3.6, labels=specialty_labels_newlines, labeldistance=0.8, colors=specialty_colours, startangle=90, counterclock=False)
plt.setp( mypie3, width=1.7, edgecolor='white')
specialty_label_colours = ['k' if i%2==0 else 'gray' for i in range(len(specialty_counts))]
for text, color in zip(texts, specialty_label_colours):
    text.set_color(color)
plt.margins(0,0)

# 3rd Ring (oUTside)
location_colours = [a(0.5),a(0.49),a(0.48),a(0.47),a(0.4),a(0.39),a(0.38),a(0.37),a(0.36),a(0.35),a(0.34),a(0.33),a(0.32),a(0.31),a(0.30),a(0.29),a(0.28),a(0.27),a(0.26),a(0.25),a(0.24),c(0.50),c(0.49),c(0.48),c(0.47),c(0.46),c(0.45),c(0.40),c(0.39),c(0.38),c(0.37),c(0.36),c(0.30),c(0.29),c(0.28),c(0.27),d(0.50),d(0.40),d(0.39),d(0.38),d(0.37),d(0.30),e(0.50),e(0.49),e(0.48),e(0.47),e(0.46),e(0.45),e(0.44),e(0.40),e(0.39),e(0.38),e(0.37)]
location_colours = []
for i,div_index in enumerate(division_counts.index):
    df_division = df[df.division == div_index]
    slice_colour_orig = 0.5
    division_care_group_counts = df_division['care_group'].value_counts()[df_division['care_group'].unique()]
    for j,care_index in enumerate(division_care_group_counts.index):
        df_care_group = df_division[df_division['care_group-location'].str.startswith(care_index)]
        per_care_group_counts = df_care_group['care_group-location'].value_counts()[df_care_group['care_group-location'].unique()]
        slice_colour = slice_colour_orig - j/10
        for k in per_care_group_counts:
            location_colours.append(inner_ring_colours[i](slice_colour))
            slice_colour -= 0.01
mypie4, texts = ax.pie(location_counts, radius=3.9, labels=location_labels, colors=location_colours, startangle=90, counterclock=False)
plt.setp( mypie4, width=0.3, edgecolor='white')
for text, color in zip(texts, location_colours):
    text.set_color(color)
plt.margins(0,0)
